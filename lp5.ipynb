# %%
import numpy as np
# X = (hours studying, hours sleeping), y = score on test, xPredicted = 4 hours studying & 8 hours sleeping (input data for prediction)
X = np.array(([2, 9], [1, 5], [3, 6]), dtype=float)
y = np.array(([92], [86], [89]), dtype=float)
xPredicted = np.array(([4,8]), dtype=float)
X = X/np.amax(X, axis=0)
xPredicted = xPredicted/np.amax(xPredicted, axis=0)
y = y/100 # max test score is 100
class Neural_Network(object):
    def __init__(self):
        self.inputSize = 2
        self.outputSize = 1
        self.hiddenSize = 3
        self.W1 = np.random.randn(self.inputSize, self.hiddenSize)
        # (3x2) weight matrix from input to hidden layer
        self.W2 = np.random.randn(self.hiddenSize, self.outputSize)
        # (3x1) weight matrix from hidden to output layer

    def forward(self, X):
        self.z = np.dot(X, self.W1)
        self.z2 = self.sigmoid(self.z) # activation function
        self.z3 = np.dot(self.z2, self.W2) # dot product of hidden layer (z2)andsecondsetof 3x1 weights
        o = self.sigmoid(self.z3) # final activation function
        return o
    
    def sigmoid(self, s): 
        return 1/(1+np.exp(-s))
    def sigmoidPrime(self, s):
        return s * (1 - s)
    
    def backward(self, X, y, o):
        self.o_error = y - o # error in output
        self.o_delta = self.o_error*self.sigmoidPrime(o) # applying derivative of sigmoid to error
        self.z2_error = self.o_delta.dot(self.W2.T) # z2 error: how much our hidden layer weights contributed to output error
        self.z2_delta = self.z2_error*self.sigmoidPrime(self.z2) # applying derivative of sigmoid to z2 error
        self.W1 += X.T.dot(self.z2_delta) # adjusting first set (input --> hidden) weights
        self.W2 += self.z2.T.dot(self.o_delta) # adjusting second set (hidden --> output) weights
    def train(self, X, y):
        o = self.forward(X)
        self.backward(X, y, o)
    def saveWeights(self):
        np.savetxt("w1.txt", self.W1, fmt="%s")
        np.savetxt("w2.txt", self.W2, fmt="%s")
    def predict(self):
        print("Predicted data based on trained weights: ")
        print("Input (scaled): \n" + str(xPredicted))
        print("Output: \n" + str(self.forward(xPredicted)))
NN = Neural_Network()
for i in range(1000): # trains the NN 1,000 times
    print("# " + str(i) + "\n")
    print("Input (scaled): \n" + str(X))
    print("Actual Output: \n" + str(y))
    print("Predicted Output: \n" + str(NN.forward(X)))
    print("Loss: \n" + str(np.mean(np.square(y - NN.forward(X)))))
    # mean sum squared loss
    print("\n")
    NN.train(X, y)
    NN.saveWeights()
    NN.predict()
# Out:
# # 0
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.43335872]
#  [0.40364726]
#  [0.42573373]]
# Loss:
# 0.2202069108943162
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.51541622]
# # 1
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.52026371]
#  [0.48472849]
#  [0.51435832]]
# Loss:
# 0.1472414935302533
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.58596555]
# # 2
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.59124651]
#  [0.55258925]
#  [0.5869896 ]]
# Loss:
# 0.0981318430574407
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.63946716]
# # 3
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.64489192]
#  [0.60508375]
#  [0.64196384]]
# Loss:
# 0.06739622895921342
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.67936507]
# # 4
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.68478102]
#  [0.64490778]
#  [0.68285786]]
# Loss:
# 0.04816683157988661
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.7095292]
# # 5
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.71486702]
#  [0.67544747]
#  [0.71369662]]
# Loss:
# 0.03574068566053303
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.73287489]
# # 6
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.73810725]
#  [0.6993625 ]
#  [0.73750741]]
# Loss:
# 0.027381122084465494
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.751386]
# # 7
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.75650542]
#  [0.71851035]
#  [0.75634604]]
# Loss:
# 0.02153772731684318
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.76639015]
# # 8
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.77139819]
#  [0.73415771]
#  [0.7715854 ]]
# Loss:
# 0.01731359875566019
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.77878675]
# # 9
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.78368894]
#  [0.7471756 ]
#  [0.78415377]]
# Loss:
# 0.014171158636955944
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.78919859]
# # 10
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.79400192]
#  [0.75817446]
#  [0.79469269]]
# Loss:
# 0.011775813263070452
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.79806732]
# # 11
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8027791 ]
#  [0.76759166]
#  [0.80365637]]
# Loss:
# 0.009911754602794549
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.80571351]
# # 12
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.81034083]
#  [0.77574741]
#  [0.81137393]]
# Loss:
# 0.008435230137338273
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.81237488]
# # 13
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.81692437]
#  [0.78288104]
#  [0.81808911]]
# Loss:
# 0.007247698654857298
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.81823121]
# # 14
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.82270895]
#  [0.78917473]
#  [0.82398594]]
# Loss:
# 0.006279874597679906
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.82342085]
# # 15
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.82783237]
#  [0.79476954]
#  [0.8292059 ]]
# Loss:
# 0.005481935933008129
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.82805196]
# # 16
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.83240229]
#  [0.79977637]
#  [0.83385945]]
# Loss:
# 0.004817335603334386
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.83221036]
# # 17
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.83650401]
#  [0.80428359]
#  [0.83803411]]
# Loss:
# 0.004258784707577921
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.83596493]
# # 18
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.840206  ]
#  [0.8083625 ]
#  [0.84180009]]
# Loss:
# 0.003785581587456136
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.83937169]
# # 19
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.84356389]
#  [0.81207129]
#  [0.8452144 ]]
# Loss:
# 0.003381796624602742
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.84247661]
# # 20
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8466233 ]
#  [0.81545793]
#  [0.84832381]]
# Loss:
# 0.0030350139292591428
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.84531782]
# # 21
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.84942204]
#  [0.8185623 ]
#  [0.85116704]]
# Loss:
# 0.0027354432451719545
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.84792719]
# # 22
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85199173]
#  [0.82141789]
#  [0.85377646]]
# Loss:
# 0.0024752827996393635
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.85033161]
# # 23
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85435899]
#  [0.82405299]
#  [0.85617934]]
# Loss:
# 0.0022482553034677906
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8525539]
# # 24
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85654643]
#  [0.82649172]
#  [0.8583988 ]]
# Loss:
# 0.0020492653860816877
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.85461355]
# # 25
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85857336]
#  [0.82875472]
#  [0.8604546 ]]
# Loss:
# 0.0018741434822342421
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.85652736]
# # 26
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86045638]
#  [0.83085982]
#  [0.86236371]]
# Loss:
# 0.001719452120528403
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.85830983]
# # 27
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86220987]
#  [0.83282247]
#  [0.86414083]]
# Loss:
# 0.0015823378324254852
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.85997361]
# # 28
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86384631]
#  [0.83465613]
#  [0.86579872]]
# Loss:
# 0.001460416809537397
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.86152973]
# # 29
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86537661]
#  [0.8363726 ]
#  [0.86734853]]
# Loss:
# 0.0013516858018012157
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.86298788]
# # 30
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86681036]
#  [0.83798227]
#  [0.86880004]]
# Loss:
# 0.0012544520872484206
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.86435661]
# # 31
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.868156  ]
#  [0.83949431]
#  [0.87016189]]
# Loss:
# 0.001167277989656763
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.86564351]
# # 32
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86942102]
#  [0.84091686]
#  [0.8714417 ]]
# Loss:
# 0.001088936592431985
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.86685529]
# # 33
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87061207]
#  [0.84225717]
#  [0.87264626]]
# Loss:
# 0.001018376141233935
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.86799797]
# # 34
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87173506]
#  [0.84352172]
#  [0.87378162]]
# Loss:
# 0.0009546912422593295
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.86907693]
# # 35
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87279532]
#  [0.84471631]
#  [0.87485319]]
# Loss:
# 0.0008970994146767467
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.870097]
# # 36
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87379761]
#  [0.84584618]
#  [0.87586584]]
# Loss:
# 0.0008449218907041985
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.87106252]
# # 37
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87474622]
#  [0.84691604]
#  [0.87682394]]
# Loss:
# 0.0007975678074994024
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.87197743]
# # 38
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87564502]
#  [0.84793014]
#  [0.87773143]]
# Loss:
# 0.0007545211241662626
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.87284528]
# # 39
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87649753]
#  [0.84889237]
#  [0.8785919 ]]
# Loss:
# 0.0007153297409905293
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.87366931]
# # 40
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87730693]
#  [0.84980622]
#  [0.87940859]]
# Loss:
# 0.0006795964081712131
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.87445246]
# # 41
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87807613]
#  [0.85067491]
#  [0.88018446]]
# Loss:
# 0.000646971096277717
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.87519742]
# # 42
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87880776]
#  [0.85150137]
#  [0.8809222 ]]
# Loss:
# 0.0006171445666310749
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.87590664]
# # 43
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87950426]
#  [0.85228828]
#  [0.88162427]]
# Loss:
# 0.0005898429313498731
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.87658238]
# # 44
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88016783]
#  [0.85303809]
#  [0.88229293]]
# Loss:
# 0.0005648230333136308
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.87722669]
# # 45
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88080051]
#  [0.85375307]
#  [0.88293025]]
# Loss:
# 0.0005418685083206624
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.87784148]
# # 46
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88140418]
#  [0.8544353 ]
#  [0.88353813]]
# Loss:
# 0.0005207864171691254
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8784285]
# # 47
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88198055]
#  [0.85508669]
#  [0.88411834]]
# Loss:
# 0.0005014043557236803
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.87898936]
# # 48
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88253123]
#  [0.85570903]
#  [0.88467248]]
# Loss:
# 0.00048356796735513904
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.87952558]
# # 49
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88305768]
#  [0.85630395]
#  [0.88520205]]
# Loss:
# 0.0004671387953087943
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88003852]
# # 50
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88356126]
#  [0.85687299]
#  [0.88570844]]
# Loss:
# 0.0004519924232282387
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88052947]
# # 51
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88404325]
#  [0.85741754]
#  [0.88619295]]
# Loss:
# 0.00043801686074547186
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88099963]
# # 52
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88450482]
#  [0.85793893]
#  [0.88665675]]
# Loss:
# 0.0004251111381450092
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88145012]
# # 53
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88494705]
#  [0.85843838]
#  [0.88710096]]
# Loss:
# 0.0004131840799328342
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88188196]
# # 54
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88537098]
#  [0.85891704]
#  [0.88752662]]
# Loss:
# 0.00040215323193682986
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88229611]
# # 55
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88577754]
#  [0.85937597]
#  [0.88793469]]
# Loss:
# 0.0003919439205300992
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88269349]
# # 56
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88616763]
#  [0.85981616]
#  [0.88832607]]
# Loss:
# 0.0003824884258576875
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88307494]
# # 57
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88654207]
#  [0.86023855]
#  [0.8887016 ]]
# Loss:
# 0.0003737252536852244
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88344124]
# # 58
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88690165]
#  [0.86064402]
#  [0.88906207]]
# Loss:
# 0.00036559849277453853
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88379314]
# # 59
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88724708]
#  [0.86103337]
#  [0.88940823]]
# Loss:
# 0.0003580572466072742
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88413133]
# # 60
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88757906]
#  [0.86140739]
#  [0.88974075]]
# Loss:
# 0.00035105512988732704
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88445646]
# # 61
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88789822]
#  [0.86176679]
#  [0.8900603 ]]
# Loss:
# 0.0003445498216100527
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88476915]
# # 62
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88820517]
#  [0.86211226]
#  [0.89036749]]
# Loss:
# 0.0003385026676330049
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88506997]
# # 63
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88850047]
#  [0.86244443]
#  [0.89066288]]
# Loss:
# 0.00033287832665524755
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88535947]
# # 64
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88878466]
#  [0.86276391]
#  [0.89094703]]
# Loss:
# 0.0003276444543383172
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88563816]
# # 65
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88905825]
#  [0.86307128]
#  [0.89122045]]
# Loss:
# 0.00032277142100582673
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88590653]
# # 66
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8893217 ]
#  [0.86336706]
#  [0.89148361]]
# Loss:
# 0.00031823205895991984
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88616503]
# # 67
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88957547]
#  [0.86365177]
#  [0.89173697]]
# Loss:
# 0.0003140014359674754
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88641409]
# # 68
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88981999]
#  [0.86392588]
#  [0.89198097]]
# Loss:
# 0.0003100566519106871
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88665413]
# # 69
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89005565]
#  [0.86418986]
#  [0.892216  ]]
# Loss:
# 0.0003063766559766589
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88688553]
# # 70
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89028283]
#  [0.86444413]
#  [0.89244246]]
# Loss:
# 0.0003029420820880163
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88710865]
# # 71
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8905019 ]
#  [0.86468911]
#  [0.89266071]]
# Loss:
# 0.0002997351005596436
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88732385]
# # 72
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89071319]
#  [0.86492518]
#  [0.8928711 ]]
# Loss:
# 0.00029673928421130794
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88753146]
# # 73
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89091703]
#  [0.86515271]
#  [0.89307395]]
# Loss:
# 0.0002939394873785241
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88773178]
# # 74
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89111374]
#  [0.86537205]
#  [0.89326958]]
# Loss:
# 0.0002913217364485442
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88792512]
# # 75
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89130359]
#  [0.86558353]
#  [0.89345828]]
# Loss:
# 0.00028887313070896154
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88811176]
# # 76
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89148687]
#  [0.86578747]
#  [0.89364033]]
# Loss:
# 0.00028658175243679435
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88829196]
# # 77
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89166385]
#  [0.86598417]
#  [0.893816  ]]
# Loss:
# 0.0002844365852782032
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.888466]
# # 78
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89183476]
#  [0.86617391]
#  [0.89398555]]
# Loss:
# 0.0002824274400763948
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8886341]
# # 79
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89199987]
#  [0.86635697]
#  [0.89414922]]
# Loss:
# 0.00028054488739916167
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8887965]
# # 80
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89215938]
#  [0.86653362]
#  [0.89430724]]
# Loss:
# 0.0002787801961001165
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88895343]
# # 81
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89231352]
#  [0.86670409]
#  [0.89445983]]
# Loss:
# 0.00027712527732033594
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88910508]
# # 82
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8924625 ]
#  [0.86686862]
#  [0.8946072 ]]
# Loss:
# 0.00027557263340108654
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88925168]
# # 83
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89260652]
#  [0.86702744]
#  [0.89474955]]
# Loss:
# 0.00027411531123479744
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88939341]
# # 84
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89274576]
#  [0.86718077]
#  [0.89488707]]
# Loss:
# 0.0002727468596312986
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88953044]
# # 85
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8928804 ]
#  [0.86732881]
#  [0.89501994]]
# Loss:
# 0.0002714612903205598
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88966297]
# # 86
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89301063]
#  [0.86747177]
#  [0.89514835]]
# Loss:
# 0.0002702530422522665
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88979115]
# # 87
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89313659]
#  [0.86760982]
#  [0.89527245]]
# Loss:
# 0.00026911694888723486
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88991516]
# # 88
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89325845]
#  [0.86774315]
#  [0.8953924 ]]
# Loss:
# 0.00026804820820668963
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89003513]
# # 89
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89337637]
#  [0.86787193]
#  [0.89550837]]
# Loss:
# 0.0002670423551926512
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89015122]
# # 90
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89349048]
#  [0.86799633]
#  [0.89562049]]
# Loss:
# 0.0002660952365573707
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89026358]
# # 91
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89360093]
#  [0.86811651]
#  [0.89572891]]
# Loss:
# 0.00026520298752138045
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89037233]
# # 92
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89370785]
#  [0.86823262]
#  [0.89583375]]
# Loss:
# 0.00026436201045933514
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8904776]
# # 93
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89381136]
#  [0.8683448 ]
#  [0.89593516]]
# Loss:
# 0.00026356895525021513
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89057953]
# # 94
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89391158]
#  [0.86845319]
#  [0.89603324]]
# Loss:
# 0.0002628207011839642
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89067823]
# # 95
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89400864]
#  [0.86855794]
#  [0.89612813]]
# Loss:
# 0.0002621143402908103
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89077381]
# # 96
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89410264]
#  [0.86865916]
#  [0.89621993]]
# Loss:
# 0.00026144716197177816
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89086638]
# # 97
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8941937 ]
#  [0.86875698]
#  [0.89630875]]
# Loss:
# 0.0002608166388205244
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89095605]
# # 98
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89428192]
#  [0.86885152]
#  [0.89639469]]
# Loss:
# 0.00026022041353634875
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89104292]
# # 99
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89436739]
#  [0.86894289]
#  [0.89647787]]
# Loss:
# 0.0002596562868377003
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89112709]
# # 100
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89445021]
#  [0.8690312 ]
#  [0.89655837]]
# Loss:
# 0.0002591222062934901
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89120865]
# # 101
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89453047]
#  [0.86911657]
#  [0.89663628]]
# Loss:
# 0.0002586162559970367
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89128769]
# # 102
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89460827]
#  [0.86919908]
#  [0.8967117 ]]
# Loss:
# 0.0002581366470140526
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8913643]
# # 103
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89468368]
#  [0.86927884]
#  [0.89678471]]
# Loss:
# 0.0002576817085422945
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89143855]
# # 104
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89475679]
#  [0.86935594]
#  [0.89685539]]
# Loss:
# 0.000257249879725742
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89151054]
# # 105
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89482768]
#  [0.86943047]
#  [0.89692383]]
# Loss:
# 0.0002568397020712839
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89158034]
# # 106
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89489641]
#  [0.86950252]
#  [0.89699009]]
# Loss:
# 0.00025644981242032487
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89164801]
# # 107
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89496307]
#  [0.86957217]
#  [0.89705426]]
# Loss:
# 0.00025607893643173686
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89171364]
# # 108
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89502772]
#  [0.8696395 ]
#  [0.8971164 ]]
# Loss:
# 0.0002557258825363387
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89177729]
# # 109
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89509044]
#  [0.86970459]
#  [0.89717658]]
# Loss:
# 0.0002553895363263866
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89183902]
# # 110
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89515128]
#  [0.86976751]
#  [0.89723487]]
# Loss:
# 0.0002550688553466485
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89189891]
# # 111
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8952103 ]
#  [0.86982833]
#  [0.89729132]]
# Loss:
# 0.00025476286425633047
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89195701]
# # 112
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89526758]
#  [0.86988713]
#  [0.89734601]]
# Loss:
# 0.0002544706503337787
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89201337]
# # 113
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89532316]
#  [0.86994398]
#  [0.89739898]]
# Loss:
# 0.0002541913592979853
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89206807]
# # 114
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8953771 ]
#  [0.86999892]
#  [0.8974503 ]]
# Loss:
# 0.0002539241914232468
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89212115]
# # 115
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89542946]
#  [0.87005204]
#  [0.89750002]]
# Loss:
# 0.00025366839792502184
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89217267]
# # 116
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89548028]
#  [0.87010338]
#  [0.89754819]]
# Loss:
# 0.00025342327759696046
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89222267]
# # 117
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89552963]
#  [0.87015301]
#  [0.89759486]]
# Loss:
# 0.00025318817368055415
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89227121]
# # 118
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89557754]
#  [0.87020097]
#  [0.89764008]]
# Loss:
# 0.00025296247095035583
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89231833]
# # 119
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89562406]
#  [0.87024734]
#  [0.8976839 ]]
# Loss:
# 0.00025274559299909175
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89236408]
# # 120
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89566924]
#  [0.87029215]
#  [0.89772637]]
# Loss:
# 0.0002525369997081333
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89240851]
# # 121
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89571312]
#  [0.87033545]
#  [0.89776752]]
# Loss:
# 0.00025233618488997863
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89245166]
# # 122
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89575574]
#  [0.8703773 ]
#  [0.8978074 ]]
# Loss:
# 0.00025214267409042477
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89249356]
# # 123
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89579715]
#  [0.87041775]
#  [0.89784606]]
# Loss:
# 0.0002519560225389856
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89253426]
# # 124
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89583738]
#  [0.87045683]
#  [0.89788352]]
# Loss:
# 0.0002517758132370661
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89257379]
# # 125
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89587647]
#  [0.87049459]
#  [0.89791984]]
# Loss:
# 0.00025160165517414986
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8926122]
# # 126
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89591445]
#  [0.87053107]
#  [0.89795503]]
# Loss:
# 0.0002514331816629606
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89264952]
# # 127
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89595137]
#  [0.87056631]
#  [0.89798915]]
# Loss:
# 0.00025127004878531953
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89268579]
# # 128
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89598725]
#  [0.87060036]
#  [0.89802223]]
# Loss:
# 0.0002511119339409271
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89272103]
# # 129
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89602213]
#  [0.87063325]
#  [0.89805429]]
# Loss:
# 0.00025095853449198644
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89275528]
# # 130
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89605605]
#  [0.87066501]
#  [0.89808537]]
# Loss:
# 0.00025080956649697867
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89278857]
# # 131
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89608902]
#  [0.87069569]
#  [0.89811551]]
# Loss:
# 0.0002506647635275228
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89282094]
# # 132
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89612108]
#  [0.87072532]
#  [0.89814472]]
# Loss:
# 0.0002505238755625796
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8928524]
# # 133
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89615227]
#  [0.87075392]
#  [0.89817305]]
# Loss:
# 0.00025038666795473575
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.892883]
# # 134
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8961826 ]
#  [0.87078154]
#  [0.89820051]]
# Loss:
# 0.00025025292046369665
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89291275]
# # 135
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8962121 ]
#  [0.8708082 ]
#  [0.89822714]]
# Loss:
# 0.00025012242635237
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89294168]
# # 136
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8962408 ]
#  [0.87083393]
#  [0.89825297]]
# Loss:
# 0.00024999499154141133
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89296983]
# # 137
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89626873]
#  [0.87085876]
#  [0.89827801]]
# Loss:
# 0.0002498704338182144
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8929972]
# # 138
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89629591]
#  [0.87088273]
#  [0.89830228]]
# Loss:
# 0.0002497485820967639
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89302384]
# # 139
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89632236]
#  [0.87090585]
#  [0.89832583]]
# Loss:
# 0.0002496292757249275
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89304975]
# # 140
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8963481 ]
#  [0.87092816]
#  [0.89834866]]
# Loss:
# 0.00024951236383603386
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89307497]
# # 141
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89637316]
#  [0.87094967]
#  [0.89837081]]
# Loss:
# 0.0002493977047418084
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89309951]
# # 142
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89639756]
#  [0.87097042]
#  [0.89839228]]
# Loss:
# 0.00024928516536395796
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8931234]
# # 143
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89642132]
#  [0.87099042]
#  [0.89841311]]
# Loss:
# 0.0002491746207017943
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89314665]
# # 144
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89644446]
#  [0.8710097 ]
#  [0.89843331]]
# Loss:
# 0.00024906595333361884
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89316929]
# # 145
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89646699]
#  [0.87102829]
#  [0.8984529 ]]
# Loss:
# 0.00024895905294958454
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89319133]
# # 146
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89648894]
#  [0.8710462 ]
#  [0.8984719 ]]
# Loss:
# 0.0002488538159140335
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89321279]
# # 147
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89651033]
#  [0.87106346]
#  [0.89849033]]
# Loss:
# 0.00024875014485536506
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8932337]
# # 148
#
# Input (scaled):
# ...
# [0.5 1. ]
# Output:
# [0.89608187]
# # 951
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89955947]
#  [0.86903115]
#  [0.89916104]]
# Loss:
# 0.00019443388818898564
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89608454]
# # 952
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89956231]
#  [0.86902817]
#  [0.89916109]]
# Loss:
# 0.00019437749062758484
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8960872]
# # 953
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89956516]
#  [0.86902519]
#  [0.89916114]]
# Loss:
# 0.0001943211158837846
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89608987]
# # 954
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.899568  ]
#  [0.86902222]
#  [0.89916118]]
# Loss:
# 0.00019426476394520558
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89609254]
# # 955
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89957084]
#  [0.86901924]
#  [0.89916123]]
# Loss:
# 0.00019420843479947384
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89609521]
# # 956
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89957368]
#  [0.86901626]
#  [0.89916128]]
# Loss:
# 0.00019415212843422837
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89609787]
# # 957
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89957652]
#  [0.86901329]
#  [0.89916132]]
# Loss:
# 0.00019409584483710398
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89610054]
# # 958
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89957937]
#  [0.86901032]
#  [0.89916137]]
# Loss:
# 0.00019403958399575441
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8961032]
# # 959
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89958221]
#  [0.86900734]
#  [0.89916141]]
# Loss:
# 0.00019398334589783176
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89610587]
# # 960
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89958505]
#  [0.86900437]
#  [0.89916146]]
# Loss:
# 0.00019392713053099358
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89610854]
# # 961
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89958788]
#  [0.8690014 ]
#  [0.8991615 ]]
# Loss:
# 0.0001938709378829159
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8961112]
# # 962
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89959072]
#  [0.86899843]
#  [0.89916155]]
# Loss:
# 0.00019381476794126583
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89611386]
# # 963
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89959356]
#  [0.86899546]
#  [0.89916159]]
# Loss:
# 0.00019375862069372562
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89611653]
# # 964
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8995964 ]
#  [0.86899249]
#  [0.89916164]]
# Loss:
# 0.0001937024961279837
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89611919]
# # 965
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89959924]
#  [0.86898952]
#  [0.89916168]]
# Loss:
# 0.0001936463942317349
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89612186]
# # 966
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89960207]
#  [0.86898656]
#  [0.89916173]]
# Loss:
# 0.0001935903149926824
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89612452]
# # 967
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89960491]
#  [0.86898359]
#  [0.89916177]]
# Loss:
# 0.00019353425839852356
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89612718]
# # 968
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89960774]
#  [0.86898063]
#  [0.89916182]]
# Loss:
# 0.00019347822443698386
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89612984]
# # 969
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89961058]
#  [0.86897766]
#  [0.89916186]]
# Loss:
# 0.0001934222130957801
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89613251]
# # 970
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89961341]
#  [0.8689747 ]
#  [0.8991619 ]]
# Loss:
# 0.00019336622436263765
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89613517]
# # 971
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89961625]
#  [0.86897174]
#  [0.89916195]]
# Loss:
# 0.00019331025822529044
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89613783]
# # 972
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89961908]
#  [0.86896878]
#  [0.89916199]]
# Loss:
# 0.00019325431467148105
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89614049]
# # 973
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89962191]
#  [0.86896582]
#  [0.89916203]]
# Loss:
# 0.00019319839368895256
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89614315]
# # 974
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89962475]
#  [0.86896286]
#  [0.89916208]]
# Loss:
# 0.00019314249526546047
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89614581]
# # 975
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89962758]
#  [0.8689599 ]
#  [0.89916212]]
# Loss:
# 0.00019308661938876467
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89614847]
# # 976
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89963041]
#  [0.86895694]
#  [0.89916216]]
# Loss:
# 0.00019303076604663318
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89615113]
# # 977
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89963324]
#  [0.86895399]
#  [0.89916221]]
# Loss:
# 0.00019297493522683914
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89615379]
# # 978
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89963607]
#  [0.86895103]
#  [0.89916225]]
# Loss:
# 0.00019291912691716105
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89615645]
# # 979
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8996389 ]
#  [0.86894808]
#  [0.89916229]]
# Loss:
# 0.00019286334110538378
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89615911]
# # 980
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89964173]
#  [0.86894512]
#  [0.89916233]]
# Loss:
# 0.00019280757777930262
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89616176]
# # 981
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89964456]
#  [0.86894217]
#  [0.89916237]]
# Loss:
# 0.00019275183692671466
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89616442]
# # 982
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89964739]
#  [0.86893922]
#  [0.89916242]]
# Loss:
# 0.00019269611853542864
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89616708]
# # 983
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89965021]
#  [0.86893627]
#  [0.89916246]]
# Loss:
# 0.00019264042259325585
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89616974]
# # 984
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89965304]
#  [0.86893332]
#  [0.8991625 ]]
# Loss:
# 0.00019258474908801784
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89617239]
# # 985
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89965587]
#  [0.86893037]
#  [0.89916254]]
# Loss:
# 0.0001925290980075345
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89617505]
# # 986
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8996587 ]
#  [0.86892742]
#  [0.89916258]]
# Loss:
# 0.00019247346933963874
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89617771]
# # 987
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89966152]
#  [0.86892447]
#  [0.89916262]]
# Loss:
# 0.00019241786307217594
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89618036]
# # 988
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89966435]
#  [0.86892152]
#  [0.89916266]]
# Loss:
# 0.00019236227919298285
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89618302]
# # 989
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89966717]
#  [0.86891858]
#  [0.89916271]]
# Loss:
# 0.0001923067176899172
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89618567]
# # 990
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89967   ]
#  [0.86891563]
#  [0.89916275]]
# Loss:
# 0.00019225117855083533
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89618833]
# # 991
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89967282]
#  [0.86891269]
#  [0.89916279]]
# Loss:
# 0.00019219566176360275
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89619098]
# # 992
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89967564]
#  [0.86890975]
#  [0.89916283]]
# Loss:
# 0.00019214016731608965
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89619363]
# # 993
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89967847]
#  [0.86890681]
#  [0.89916287]]
# Loss:
# 0.00019208469519617087
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89619629]
# # 994
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89968129]
#  [0.86890386]
#  [0.89916291]]
# Loss:
# 0.0001920292453917383
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89619894]
# # 995
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89968411]
#  [0.86890092]
#  [0.89916295]]
# Loss:
# 0.00019197381789067396
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89620159]
# # 996
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89968693]
#  [0.86889798]
#  [0.89916299]]
# Loss:
# 0.00019191841268088376
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89620425]
# # 997
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89968975]
#  [0.86889505]
#  [0.89916303]]
# Loss:
# 0.00019186302975026412
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8962069]
# # 998
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89969257]
#  [0.86889211]
#  [0.89916307]]
# Loss:
# 0.00019180766908673098
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89620955]
# # 999
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89969539]
#  [0.86888917]
#  [0.8991631 ]]
# Loss:
# 0.00019175233067819728
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8962122]
